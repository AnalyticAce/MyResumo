# %%
# import weasyprint

# doc_pdf = weasyprint.HTML("https://www.delftstack.com/").write_pdf("sample.pdf")

# %%
# !pip install pdfkit

# %%
# import pdfkit 
# pdfkit.from_file('../template/index.html', 'test.pdf')

# %%
# from weasyprint import HTML, CSS
# from weasyprint.text.fonts import FontConfiguration

# font_config = FontConfiguration()
# html = HTML(string='<h1>The title</h1>')
# css = CSS(string='''
#     @font-face {
#         font-family: Gentium;
#         src: url(https://example.com/fonts/Gentium.otf);
#     }
#     h1 { font-family: Gentium }''', font_config=font_config)
# html.write_pdf(
#     'example.pdf', stylesheets=[css],
#     font_config=font_config)

# %%
data = {
    "user_information": {
        "name": "DOSSEH Shalom",
        "main_job_title": "Data Analyst / Scientist",
        "profile_description": "Passionate and dynamic individual with a strong background in computer expertise. Currently pursuing a Bachelor's degree in Computer Science with a keen interest in data analysis and quantitative finance. Fluent in English and French.",
        "email": "dossehdosseh14@gmail.com",
        "linkedin": "https://www.linkedin.com/in/shalom-dosseh-4a484a262",
        "github" : 'Test github',
        "experiences": [
            {
                "job_title": "Freelance Digital Marketer",
                "company": "Self-Employed",
                "start_date": "September 2022",
                "end_date": "Present",
                "tasks": [
                    "Successfully completed 1 digital marketing project.",
                    "Executed 2 Facebook chatbot projects.",
                    "Delivered over 10 graphic design projects."
                ]
            }
        ],
        "education": [
            {
                "institution": "Epitech Bénin",
                "degree": "Bachelor's in Computer Science",
                "description": "Currently pursuing a Bachelor's degree in Computer Science.",
                "start_date": "September 2021",
                "end_date": "Present"
            },
            {
                "institution": "Trinity College Cotonou",
                "degree": "West African Senior School Certificate Examination",
                "description": "Completed the West African Senior School Certificate Examination.",
                "start_date": "September 2019",
                "end_date": "June 2022"
            }
        ],
        "skills": {
            "hard_skills": [
                "Microsoft Excel",
                "SQL",
                "Python",
                "C Programming"
            ],
            "soft_skills": [
                "Teamwork",
                "Problem-solving",
                "Creativity/Innovation"
            ]
        },
        "hobbies": []
    },
    "projects": [
        {
            "project_name": "Binance CopyTrading Alert",
            "two_goals_of_the_project": [
                "Developed a Python-based trading alert system for Binance.",
                "Implemented strategies to enhance trading efficiency and profitability."
            ],
            "project_end_result": "A functional trading alert system for Binance users."
        },
        {
            "project_name": "Need4Stek",
            "two_goals_of_the_project": [
                "Utilized artificial intelligence to develop Need4Stek platform.",
                "Enhanced user experience and engagement through AI-driven features."
            ],
            "project_end_result": "Successful deployment of an AI-powered platform, Need4Stek."
        },
        {
            "project_name": "Epytodo",
            "two_goals_of_the_project": [
                "Contributed to the development of Epytodo, a web development project.",
                "Implemented features to improve task management and user interaction."
            ],
            "project_end_result": "A fully functional web application for task management, Epytodo."
        },
        {
            "project_name": "Segmentation and Financial Prediction",
            "two_goals_of_the_project": [
                "Conducted segmentation and prediction analysis in finance.",
                "Utilized data analysis techniques to predict financial trends."
            ],
            "project_end_result": "Accurate financial segmentation and prediction models."
        },
        {
            "project_name": "Pushswap",
            "two_goals_of_the_project": [
                "Developed Pushswap algorithm in C programming language.",
                "Optimized algorithm efficiency for sorting purposes."
            ],
            "project_end_result": "An efficient sorting algorithm, Pushswap, implemented in C."
        },
        {
            "project_name": "S&P 500 Equity Weighted",
            "two_goals_of_the_project": [
                "Created S&P 500 Equity Weighted algorithm for algorithmic trading.",
                "Implemented strategies to optimize equity weighting for trading purposes."
            ],
            "project_end_result": "Successful algorithm for equity weighting in S&P 500 trading."
        },
    ],
    "certifications": [
        {
            "name": "Python for Data Science and Machine Learning Bootcamp",
            "institution": "Udemy",
            "description": "Learn how to use NumPy, Pandas, Seaborn, Matplotlib, Plotly, Scikit-Learn, Machine Learning, Tensorflow, and more!",
            "date": "2022"
        },
        {
            "name": "SQL for Data Science",
            "institution": "Coursera",
            "description": "Learn the basics of SQL and start working with databases today!",
            "date": "2022"
        },
        {
            "name": "Data Science and Machine Learning Bootcamp with R",
            "institution": "Udemy",
            "description": "Learn how to use the R programming language for data science and machine learning!",
            "date": "2022"
        }
    ],
    "extra_curricular_activities": [
        {
            "name": "Hackathon",
            "description": "Participated in a hackathon event and developed a web application for task management."
        },
        {
            "name": "Data Science Workshop",
            "description": "Attended a data science workshop and learned about data analysis and machine learning techniques."
        },
        {
            "name": "Coding Bootcamp",
            "description": "Completed a coding bootcamp and gained practical experience in software development."
        }
    ]
}

from weasyprint import HTML, CSS
from weasyprint.text.fonts import FontConfiguration

def parse_user_information(data):
    user_information = data["user_information"]
    if user_information["name"] == '':
        return ""
    if user_information["main_job_title"] == '':
        return ""
    if user_information["profile_description"] == '':
        return ""
    if user_information["email"] == '':
        return ""
    if user_information["linkedin"] == '':
        return ""
    if user_information["github"] == []:
        return ""
    user_information_html = f"""
    <header>
        <h1 style="text-align: center;">{user_information['name']}</h1>
        <p style="text-align: center;">{user_information['main_job_title']}</p>
        <p style="text-align: center;">{user_information['email']} - 
            {user_information['linkedin']} - {user_information["github"]}</p>
        <h2>SUMMARY</h2>
        <p>{user_information['profile_description']}</p>
    </header>
    """
    return user_information_html

def parse_experiences(data):
    experiences = data["user_information"]["experiences"]
    if experiences == []:
        return ""
    experiences_html = "<section><h2>EXPERIENCE</h2>"
    for experience in experiences:
        experience_html = f"""
        <h3>{experience['job_title']} at {experience['company']} - {experience['start_date']} to {experience['end_date']}</h3>
        <ul>
        """
        for task in experience["tasks"]:
            experience_html += f"<li>{task}</li>"
        experience_html += "</ul>"
        experiences_html += experience_html
    experiences_html += "</section>"
    return experiences_html

def parse_education(data):
    education = data["user_information"]["education"]
    if education == []:
        return ""
    education_html = "<section><h2>EDUCATION</h2>"
    for institution in education:
        institution_html = f"""
        <h3>{institution['degree']} at {institution['institution']} - {institution['start_date']} to {institution['end_date']}</h3>
        <p>{institution['description']}</p>
        """
        education_html += institution_html
    education_html += "</section>"
    return education_html

def parse_skills(data):
    skills = data["user_information"]["skills"]
    if skills["hard_skills"] == [] and skills["soft_skills"] == []:
        return ""
    skills_html = "<section><h2>SKILLS</h2>"
    skills_html += "<h3>Hard Skills</h3><ul>"
    hard_skills = ", ".join(skills["hard_skills"])
    skills_html += f"<li>{hard_skills}</li>"
    skills_html += "</ul>"
    skills_html += "<h3>Soft Skills</h3><ul>"
    soft_skills = ", ".join(skills["soft_skills"])
    skills_html += f"<li>{soft_skills}</li>"
    skills_html += "</ul></section>"
    return skills_html

def parse_projects(data):
    projects = data["projects"]
    if projects == []:
        return ""
    projects_html = "<section><h2>PROJECTS</h2>"
    for project in projects:
        project_html = f"""
        <h3>{project['project_name']}</h3>
        <ul>
            <li>{project['two_goals_of_the_project'][0]}</li>
            <li>{project['two_goals_of_the_project'][1]}</li>
            <li>{project['project_end_result']}</li>
        </ul>
        """
        projects_html += project_html
    projects_html += "</section>"
    return projects_html

def parse_hobbies(data):
    if data["user_information"]["hobbies"] == []:
        return ""
    hobbies = data["user_information"]["hobbies"]
    hobbies_html = "<section><h2>HOBBIES</h2><ul>"
    for hobby in hobbies:
        hobbies_html += f"<li>{hobby}</li>"
    hobbies_html += "</ul></section>"
    return hobbies_html

def parse_certifications(data):
    certifications = data["certifications"]
    if certifications == []:
        return ""
    certifications_html = "<section><h2>CERTIFICATIONS</h2>"
    for certification in certifications:
        certification_html = f"""
        <h3>{certification['name']} at {certification['institution']} - {certification['date']}</h3>
        <p>{certification['description']}</p>
        """
        certifications_html += certification_html
    certifications_html += "</section>"
    return certifications_html

def parse_extra_curricular_activities(data):
    extra_curricular_activities = data["extra_curricular_activities"]
    if extra_curricular_activities == []:
        return ""
    extra_curricular_activities_html = "<section><h2>EXTRA-CURRICULAR ACTIVITIES</h2>"
    for activity in extra_curricular_activities:
        activity_html = f"""
        <h3>{activity['name']}</h3>
        <p>{activity['description']}</p>
        """
        extra_curricular_activities_html += activity_html
    extra_curricular_activities_html += "</section>"
    return extra_curricular_activities_html

def create_resume(data):
    user_information_html = parse_user_information(data)
    experiences_html = parse_experiences(data)
    education_html = parse_education(data)
    skills_html = parse_skills(data)
    projects_html = parse_projects(data)
    hobbies_html = parse_hobbies(data)
    certificates_html = parse_certifications(data)
    extra_curricular_activities_html = parse_extra_curricular_activities(data)
    resume_html = f"""
    <!DOCTYPE html>
    <html>
    <head>
        <link rel="stylesheet" href="index.css">
    </head>
    <body>
        {user_information_html}
        {experiences_html}
        {education_html}
        {certificates_html}
        {projects_html}
        {extra_curricular_activities_html}
        {skills_html}
        {hobbies_html}
    </body>
    </html>
    """
    return resume_html
    
def perfect_css_style():
    css = """
    body {
        font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;
        font-size: 12px;
        line-height: 1.4;
        background-color: #ffffff;
        margin: 0;
        padding: 0;
    }

    header, section {
        padding: 10px 20px;
    }

    header h1 {
        font-size: 36px;
        color: #333333;
    }

    header p, header a, section a {
        font-size: 13px;
        color: #333333;
        text-decoration: none;
    }

    h2 {
        font-size: 9px;
        color: #333333;
        border-bottom: 1px solid #dddddd;
        padding-bottom: 5px;
        margin-top: 30px;
        margin-bottom: 10px;
    }

    h3 {
        font-size: 12px;
        color: #333333;
    }

    ul {
        padding: 0;
    }

    ul li {
        list-style: disc;
        margin-bottom: 2px;
    }

    a:hover {
        text-decoration: underline;
    }

    @media print {
        body {
            background-color: #ffffff;
        }

        header, section {
            padding: 0;
            border: none;
        }

        h2 {
            font-size: 20px;
            border-bottom: 1px solid #333333;
        }
    }
    """
    return css

def create_pdf(data, filename):
    font_config = FontConfiguration()
    html = HTML(string=f"""{create_resume(data)}""")
    css = CSS(string=f'''{perfect_css_style()}''', font_config=font_config)
    html.write_pdf(filename, stylesheets=[css], font_config=font_config)

create_pdf(data, "shalom_dosseh_resume.pdf")

print(create_resume(data))
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#         <link rel="stylesheet" href="index.css">
#     </head>
#     <body>
#
#     <header>
#         <h1 style="text-align: center;">DOSSEH Shalom</h1>
#         <p style="text-align: center;">Data Analyst / Scientist</p>
#         <p style="text-align: center;">dossehdosseh14@gmail.com -
#             https://www.linkedin.com/in/shalom-dosseh-4a484a262 - Test github</p>
#         <h2>SUMMARY</h2>
#         <p>Passionate and dynamic individual with a strong background in computer expertise. Currently pursuing a Bachelor's degree in Computer Science with a keen interest in data analysis and quantitative finance. Fluent in English and French.</p>
#     </header>
#
#         <section><h2>EXPERIENCE</h2>
#         <h3>Freelance Digital Marketer at Self-Employed - September 2022 to Present</h3>
#         <ul>
# ...
