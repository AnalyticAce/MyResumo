# %%
from pdf2image import convert_from_path
import cv2
import os
import matplotlib.pyplot as plt
import pytesseract

filename = '../Data/CV-Pancrace KPOAHOUN.pdf'
images = convert_from_path(filename)

def pdf_to_image(pdf_file):
    images = convert_from_path(pdf_file)
    return images

images = pdf_to_image(filename)

def save_images(images, filename):
    save_images_name = []
    for i in range(len(images)):
        main = filename.replace('.pdf', "").replace(" ", "_")
        images[i].save(f'{main}_page'+ str(i) +'.jpg', 'JPEG')
        save_images_name.append(f'{main}_page'+ str(i) +'.jpg')
    return save_images_name

save_images_name = save_images(images, filename)

def draw_rectangles(images, rectangles, color=(0, 255, 0), thickness=2):
    for (x, y, w, h) in rectangles:
        cv2.rectangle(image, (x, y), (x+w, y+h), color, thickness)
    return image

# rgb color
# red = (255, 0, 0)
# green = (0, 255, 0)
# blue = (0, 0, 255)
# yellow = (255, 255, 0)
# magenta = (255, 0, 255)
# cyan = (0, 255, 255)
# black = (0, 0, 0)
# white = (255, 255, 255)
def segment_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    kernel = np.ones((5, 5), np.uint8)
    dilated = cv2.dilate(binary, kernel, iterations=1)
    contours, _ = cv2.findContours(dilated, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    rectangles = [cv2.boundingRect(contour) for contour in contours]
    return draw_rectangles(image.copy(), rectangles, color=(0, 255, 255), thickness=2)

def plot_image(image):
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

for i in save_images_name:
    image = cv2.imread(i)
    segmented_image = segment_image(image)
    plot_image(segmented_image)

# print(pytesseract.image_to_string(cv2.imread(save_images_name[0])))
# print(pytesseract.image_to_string(cv2.imread(save_images_name[1])))

# %%
from pdf2image import convert_from_path
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
import pytesseract

filename = 'DOSSEH Shalom.pdf'
images = convert_from_path(filename)

def pdf_to_image(pdf_file):
    images = convert_from_path(pdf_file)
    return images

images = pdf_to_image(filename)

def save_images(images, filename):
    save_images_name = []
    for i in range(len(images)):
        main = filename.replace('.pdf', "").replace(" ", "_")
        images[i].save(f'{main}_page'+ str(i) +'.jpg', 'JPEG')
        save_images_name.append(f'{main}_page'+ str(i) +'.jpg')
    return save_images_name

save_images_name = save_images(images, filename)

def draw_rectangles(images, rectangles, color=(0, 255, 0), thickness=2):
    for (x, y, w, h) in rectangles:
        cv2.rectangle(image, (x, y), (x+w, y+h), color, thickness)
    return image

# rgb color
# red = (255, 0, 0)
# green = (0, 255, 0)
# blue = (0, 0, 255)
# yellow = (255, 255, 0)
# magenta = (255, 0, 255)
# cyan = (0, 255, 255)
# black = (0, 0, 0)
# white = (255, 255, 255)
def segment_image(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    kernel = np.ones((5, 5), np.uint8)
    dilated = cv2.dilate(binary, kernel, iterations=1)
    contours, _ = cv2.findContours(dilated, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    rectangles = [cv2.boundingRect(contour) for contour in contours]
    return draw_rectangles(image.copy(), rectangles, color=(0, 255, 0), thickness=2)

def plot_image(image):
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

for i in save_images_name:
    image = cv2.imread(i)
    segmented_image = segment_image(image)
    plot_image(segmented_image)

# %%
from pdf2image import convert_from_path
import cv2
import os
import pytesseract

def pdf_to_image(pdf_file):
    images = convert_from_path(pdf_file)
    return images

def save_images(images, filename):
    save_images_name = []
    for i in range(len(images)):
        main = filename.replace('.pdf', "").replace(" ", "_")
        images[i].save(f'{main}_page'+ str(i) +'.jpg', 'JPEG')
        save_images_name.append(f'{main}_page'+ str(i) +'.jpg')
    return save_images_name

def delete_image(images):
    for i in images:
        os.remove(i)
    return None

def ocr_image(images):
    texts = []
    for image in images:
        text = pytesseract.image_to_string(cv2.imread(image))
        texts.append(text)
    return texts

filename = '../Data/DOSSEH_SHALOM_CV.pdf'
images = convert_from_path(filename)
save_images_name = save_images(images, filename)
images = pdf_to_image(filename)
texts = ocr_image(save_images_name)

for text in texts:
    print(text)

delete_image(save_images_name)
# Out:
# Shalom DOSSEH
#
# shalom.dosseh@epitech.eu [] +22955202424 [i https://www.linkedin.com/in/shalom-dosseh-4a484a262/ ©) https://github.com/AnalyticAce
#
# APROPOS
#
# Data Analyste/Business avec une solide base en analyse technique et business. Possédant une maitrise avancée des outils d’analyse de
#
# données tels que Excel, SQL, Python, R et Tableau. Capable de transformer des données complexes en informations commerciales utiles.
# Reconnu pour son attention aux détails et sa capacité a identifier les besoins d'affaire. Cherche a utiliser ces compétences pour faciliter la
#
# prise de décision basée sur les données.
#
# EXPERIENCES
#
# Data Analyst
# Gozem Africa - First African Super App September 2023 - January 2024, Benin
# + Pilote la prise de décision grace a une analyse de données exhaustive.
#
# + Surveille les indicateurs de performance avec des tableaux de bord en temps réel.
#
# + Assure l’intégrité des données par des verifications réguliéres et la détection proactive d’anomalies.
#
# + Anticipe les tendances en élaborant des modeéles prédictifs a l'aide d’analyse statistique et d’apprentissage automatique.
#
# + Automatise les taches et réduit les erreurs grace a la maitrise de la programmation et la rédaction de scripts.
#
# + Résout les défis complexes des données a la source grace a une pensée analytique et des compétences en résolution de problémes.
#
# + Utilise des techniques d’analyse de données avancées pour détecter et prévenir les activités frauduleuses.
#
# EDUCATION
#
# Bachelors in Innovation and Information System Technology
# EPITECH - European Institute of Technology » Benin «2025
# + Acquis une expérience pratique en Innovation et Technologie en dirigeant plus de 100 projets et en exécutant avec succés plus de 120
#
# projets divers.
#
# West African Examination Council Certificate (Comptabilité)
# Trinity College Cotonou «Benin +2022
# + Dipléme de meilleur étudiant en comptabilité, commerce et technologies de l'information et de la communication
#
# PROJETS
#
# MyResumo
# December 2023 -March 2024
# + Objectif : MyResumo, un logiciel d’intelligence artificielle congu pour optimiser et améliorer votre Curriculum Vitae.
#
# + Défi: Elaboration et intégration d’un systéme avancé d’IA pour la création de CV.
# + Résultats : Une plateforme intelligente qui booste vos perspectives d’embauche.
#
# EcoScan
#
# November 2022 - December 2022
#
# + Objectif : Développement d’un systéme d’intelligence artificielle capable de reconnaitre une plante et ses propriétés a partir d’une
# simple photo.
#
# + Défi: Ventrainement d’un modeéle d’intelligence artificielle sophistiqué pour la reconnaissance des plantes.
#
# + Résultat : Une application mobile innovante qui réussit a identifier une plante et a révéler ses vertus dans 70% des cas.
#
# CERTIFICATIONS
#
# Professional Data Analyst Certification
# Datacamp.com
# + Certifie ma capacité 4 occuper un poste d'analyste de données et autre poste analytique.
#
# ACTIVITES EXTRASCOLAIRES
#
# Chef de Projet Principal
# Epitech - Bureau des Etudiants » March 2024 - Present
# + Joue un réle clé dans la coordination et la gestion des projets étudiants.
#
# + Assure le bon déroulement des initiatives, de la conception a la réalisation, tout en favorisant la collaboration et engagement des
# étudiants.
#
# + Supervision des équipes de projet, de la gestion des ressources et de la garantie de la qualité des résultats.
#
# + Point de contact principal pour toutes les communications liées au projet.
#
# Membre Exécutif & Assistant Trésorier
#
# Epitech + Programme Epitech X Impact * December 2023 - Present
#
# + Assister le trésorier principal dans le suivi des transactions financiéres de l'association.
#
# + Maintenir et organiser les documents financiers tels que les factures, les recus et les relevés bancaires.
#
# + Préparer des rapports financiers réguliers pour fournir un apercu clair de la situation financiére de l’association.
#
# + Gérer les taches administratives liées a la gestion financiére, telles que la préparation de documents pour les audits, la saisie de données
# dans le systéme comptable et la coordination des remboursements ou des paiements.
#
# Organisateur d’événements et Coordinateurs
# Google Developer Students Club * November 2023 - Present
# + Créer des événements percutants qui offrent des opportunités d’apprentissage précieuses.
#
# + Favorise la collaboration et mettent en évidence les possibilités excitantes dans le monde de la technologie au sein de la communauté
# tech.
#
# + Responsable de la planification, de la coordination et de l’exécution d’une variété d’événements, allant des ateliers techniques aux
# conférences et hackathons.
#
# + Responsable de la création de la vision et du theme, de la suggestion de dates appropriées et de l’élaboration d’un budget réalisable.
#
# SKILLS
#
# Compétence Technique: SQL, VBA, Python, R, Bash, C++, Programmation Unix
#
# Outils de Travail : Excel, Microsoft Office Suite, BigQuery, SQL Server, PostgreSQL, Power BI, Tableau, Looker Studio
#
# Soft Skills: Collaborative Leadership, Creative Problem solving , Communication, Active Listening, Self-Educator, Honesty,
# Integrity
#
# Langues: English (Bilingue), French (Native), Fon (Native)
